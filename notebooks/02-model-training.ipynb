# %% [markdown]
# **Objetivo:** Treinar e avaliar o modelo de classificação.
#
# **Conteúdo:**
#
# *   Carregar o dataset pré-processado do notebook anterior.
# *   Dividir os dados em conjuntos de treinamento e teste.
# *   Explicar a escolha do modelo Random Forest.
# *   Treinar o modelo e salvar o arquivo .pkl na pasta /models.
# *   Avaliar o desempenho do modelo usando métricas como acurácia, precisão, recall e F1-score.
