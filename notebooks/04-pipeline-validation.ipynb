# %% [markdown]
# **Objetivo:** Executar o pipeline de ponta a ponta.
#
# **Conteúdo:**
#
# *   Carregar os modelos e os dados necessários.
# *   Criar um pequeno script ou função que simule a entrada de um relato de paciente, chame o contêiner do SLM para extrair os sintomas e passe os resultados para o modelo Random Forest.
# *   Demonstrar a geração da recomendação e da justificativa final, mostrando a fluidez do processo.
