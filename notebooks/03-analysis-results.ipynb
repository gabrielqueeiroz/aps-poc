# %% [markdown]
# **Objetivo:** Analisar a interpretabilidade do modelo com SHAP.
#
# **Conteúdo:**
#
# *   Carregar o modelo treinado.
# *   Aplicar o SHAP para gerar os valores de contribuição das características.
# *   Criar visualizações dos resultados do SHAP, como gráficos de resumo ou plots de força, para entender como o modelo toma suas decisões.
# *   Usar exemplos específicos de pacientes para demonstrar como o SHAP gera uma justificativa para a recomendação.
